# %% [markdown]
# # The Battle of Neighborhoods

# %% [markdown]
# ## Introduction:

# %% [markdown]
# The main goal of this Project is to help people in to get better facilities around their neighborhood. It will also help people making smart and efficient decision on selecing great neighborood out of numbers of the other neighborhoods in Scarborough,Toranto.

# %% [markdown]
# We know that lots of people relocate to various states of Canada and they needed lots of research like:
#                <ul>
#                     <li>1 - Good Housing Prices</li>
#                     <li>2 - Reputated schools for their children.</li>
#                     <li>3 - Bases on distance of stations like how far it is station?</li>
#                 </ul>
# This project is for people who are looking for better neighborhoods.
# For ease of accessing to Cafe, School, Super market, medical shops, grocery shops, mall, theatre, hospital, like minded people, etc.

# %% [markdown]
# This Project aim to create an analysis of features for a people relocate or come to Scarborough to search a best neighborhood as a comparative analysis between neighborhoods.
# The features include in it is following:
#      <ul>
#                     <li>1 - Median housing price</li>
#                     <li>2 - Better school according to ratings</li>
#                     <li>4 - Road Connectivity</li>
#                     <li>5 - Water Resources for Domestic usage</li>
#                     <li>6 - Recreational facilities</li>
#                     <li>7 - Crime rates of that particular area</li>
#                 </ul>
# It will help the People to get the best place according to above factors before they actually relocate or migrate there.

# %% [markdown]
# ## Problem Which Tried to Solve:

# %% [markdown]
# The main goal of this Project is to help people in to get better facilities around their neighborhood. Connectivity to the airport, bus stand, city center, markets and other daily needs things nearby.
#     <ul>
#         <li> Sorted list of schools in terms of location, fees, rating and reviews</li>
#         <li>Sorted list of house in terms of housing prices in a ascending or descending order</li>
#     </ul>

# %% [markdown]
# ## The Location:

# %% [markdown]
# Scarborough is a popular destination for new migrants in Canada to reside. As a result, it is one of the most Distinct and cultural areas in the Greater Toronto Area, being home to various religious groups and places of worship.Migration has become a hot topic over the past few years with more governments seeking more restrictions on immigrants and refugees, the general trend of immigration into Canada has been one of on the rise

# %% [markdown]
# ## Foursquare API:

# %% [markdown]
# We are going to use the best prime data gathering according to places, API is Foursquare API.
# It will give you benefit of perform location search, locatin sharing, details about a business

# %% [markdown]
# ## Work Flow:

# %% [markdown]
# Using credentials of Foursquare API features of near-by places of the neighborhoods would be mined. Due to http request limitations the number of places per neighborhood parameter would reasonably be set to 100 and the radius parameter would be set to 500.

# %% [markdown]
# ## Clustering Approach:

# %% [markdown]
# Here we are going to  compare the similarities of two cities, we decided to explore neighborhoods, segment them, and group them into clusters to find similar neighborhoods in a big city like New York and Toronto. To be able to do that, we need to cluster data which is a form of unsupervised machine learning: k-means clustering algorithm

# %% [markdown]
# ## Libraries Which are Used to Develope the Project:

# %% [markdown]
# Scikit Learn: For importing k-means clustering.
#
# Pandas: For creating and manipulating dataframes.
#
# Folium: Python visualization library would be used to visualize the neighborhoods cluster distribution of using interactive leaflet map.
#
# JSON: Library to handle JSON files.
#
# Geocoder: To retrieve Location Data.
#
# Beautiful Soup and Requests: To scrap and library to handle http requests.
#
# XML: To separate data from presentation and XML stores data in plain text format.
#
# Matplotlib: Python Plotting Module.
